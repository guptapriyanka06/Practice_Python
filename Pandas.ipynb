# %%
import pandas as pd

# %%
#reading csv file

# %%
df=pd.read_csv("titanic.csv")

# %%
pwd()
# Out:
# 'C:\\Users\\Administrator\\INeuron\\Sudh_Classes2021'

# %% [markdown]
# import chardet
# with open("titanic.csv", 'rb') as rawdata:
#     result = chardet.detect(rawdata.read(100000))
# result

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2=pd.read_csv("titanic.csv")

# %%
#html page has 2 tabular data through url

# %%
df3=pd.read_html('https://www.basketball-reference.com/leaders/orb_top_10.html')

# %%
type(df3)
# Out:
# list

# %%
df3
# Out:
# [     Season   Lg                 1st                                2nd  \
#  0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
#  1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
#  2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
#  3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
#  4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
#  5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
#  6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
#  7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
#  8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
#  9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
#  10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
#  11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %%
len(df3)
# Out:
# 1

# %%
df3[0]
# Out:
#      Season   Lg                 1st                                2nd  \
# 0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
# 1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
# 2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
# 3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
# 4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
# 5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
# 6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
# 7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
# 8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
# 9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
# 10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
# 11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %%
#html page has 2 tabular data through url

# %%
df4=pd.read_html('https://www.basketball-reference.com/teams/')

# %%
len(df4)
# Out:
# 2

# %%
df4[0]
# Out:
#                 Franchise   Lg     From       To  Yrs     G     W     L  \
# 0           Atlanta Hawks  NBA  1949-50  2020-21   72  5691  2807  2884
# 1           Atlanta Hawks  NBA  1968-69  2020-21   53  4273  2109  2164
# 2         St. Louis Hawks  NBA  1955-56  1967-68   13  1005   553   452
# 3         Milwaukee Hawks  NBA  1951-52  1954-55    4   281    91   190
# 4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2   132    54    78
# ..                    ...  ...      ...      ...  ...   ...   ...   ...
# 80     Washington Bullets  NBA  1974-75  1996-97   23  1886   887   999
# 81        Capital Bullets  NBA  1973-74  1973-74    1    82    47    35
# 82      Baltimore Bullets  NBA  1963-64  1972-73   10   813   401   412
# 83        Chicago Zephyrs  NBA  1962-63  1962-63    1    80    25    55
# 84        Chicago Packers  NBA  1961-62  1961-62    1    80    18    62
#
#      W/L%  Plyfs  Div  Conf  Champ
# 0   0.493     47   12     0      1
# ...

# %%
#dataset in github, separated by tab..not so readable

# %%
pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv')
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
#now using tab as separator for above link data

# %%
d=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df6=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
df5
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 156, dtype: int64

# %%
d['Parch']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 151    0
# 152    0
# 153    2
# 154    0
# 155    1
# Name: Parch, Length: 156, dtype: int64

# %%
#trying to fetch from two cols- use list in dataframe

# %%
d['Survived','Parch']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Survived', 'Parch')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-de5e569be43b> in <module>
# ...

# %%
d[['Survived','Parch']]
# Out:
#      Survived  Parch
# 0           0      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           0      0
# ..        ...    ...
# 151         1      0
# 152         0      0
# 153         0      2
# 154         0      0
# 155         0      1
#
# [156 rows x 2 columns]

# %%
#Series-only 1 row or col fetching through df

# %%
type(d['Survived'])
# Out:
# pandas.core.series.Series

# %%
#return type dataframe- because of tabular format

# %%
type(d[['Survived']])
# Out:
# pandas.core.frame.DataFrame

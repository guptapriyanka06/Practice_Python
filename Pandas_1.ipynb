# %% [markdown]
# #The OS module in Python provides a way of using operating system dependent functionality.
# The functions that the OS module provides allows
# you to interface with the underlying operating system that Python is running on – be that Windows, Mac or Linux.
# Because it is not a built-in function, you must always import it. It is a part of the standard library, however,
# so you will not need to download or install it separately from your Python installation.

# %%
df.dropna() #drop all nan values
df.dropna(axis=0) #drop all nan values rowwise   axis=1==>colwise
df.dropna(axis=0, thres=1)  #theshold 1 means if no. of non null values in the row is <1 then it will del the row otherwise not
df.fillna()
groupby:
    g=df.groupby('col')
    g.aggfun
    g.sum()[['Survived','Fare']]
    
    JOINS:
    -------
    Must read:
        https://www.analyticsvidhya.com/blog/2020/02/joins-in-pandas-master-the-different-types-of-joins-in-python/
    
    Outer Joins:
    ------------    
    left Outer join==>
    df1.merge(df2,on='common_key',how='left')
    right Outer join==>
    df1.merge(df2,on='common_key',how='right')
    Full outer join==>
    df1.merge(df2,on='common_key',how='outer')
    
    Inner Join:
    -------------
    df1.merge(df2,on='common_key')
    
    As you can see, we have duplicate rows in the resulting dataset as well. To solve this, there is a validate argument in the merge() function, which we can set to ‘one_to_one’, ‘one_to_many’, ‘many_to_one’, and ‘many_to_many’.

    This ensures that there exists only a particular mapping across both the dataframes. If the mapping condition is not satisfied, then it throws a MergeError. To solve this, we can delete duplicates before applying join:

        pd.merge(df1.drop_duplicates(),df2,how='inner',on='common_key')
        
    But, if you want to keep these duplicates, then you can give validate values as per your requirements and it will not throw an error:

        pd.merge(df1,df2,how='inner',on='Product_ID',validate='many_to_many')
        
    Cross Join:
    -----------------
    Now to perform cross join, we will create  a key column in both the DataFrames to merge on that key.
    df1['new_keycol']=1
    df2['new_keycol']=1
    # to obtain the cross join we will merge on the key and drop it.
    df1.merge(df2, on="new_keycol").drop("new_keycol",1)
    
    to show result from two cols after cross join:
        final.loc[:,['UserID', 'ProductID']]
    
    Merge Vs join
    very little difference. Need to specify the row indexed in case of Join.
    
    For Join two more DFs, if they have same cols then change the name of cols using lsuffix or r suffix to make all cols in all dfs diff then join will work.
    
    APPLY function:
        can apply any fun on given data of DF or can generate new data
        equivalent to  map operation in python

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})
df['States']="CA NV AZ".split()
df.set_index('States',inplace=True)
df
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df.dropna()
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1

# %%
df
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df.dropna(axis=0)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#         C
# States
# CA      1
# NV      2
# AZ      3

# %%
df
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df.dropna(axis=0, thresh=1)  #not deleted bcoz no of non null values in each row are >1
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df.dropna(axis=0, thresh=2) #deleted last row bcoz no of non null values in that row are <2
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2

# %%
df
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3

# %%
df.fillna(value="K")  #replace nan values by specified values
# Out:
#         A  B  C
# States
# CA      1  5  1
# NV      2  K  2
# AZ      K  K  3

# %%
df.fillna(value=df['A'].mean())
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  1.5  2
# AZ      1.5  1.5  3

# %%
df_titanic=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # GroupBy()

# %%
g=df_titanic.groupby('Sex')

# %%
g.mean()
# Out:
#         PassengerId  Survived    Pclass        Age  SibSp     Parch       Fare
# Sex
# female       68.125  0.714286  2.464286  24.468085  0.875  0.517857  28.460639
# male         84.310  0.140000  2.400000  30.326962  0.470  0.330000  27.912998

# %%
df_titanic.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age  SibSp     Parch       Fare
# Sex
# female       68.125  0.714286  2.464286  24.468085  0.875  0.517857  28.460639
# male         84.310  0.140000  2.400000  30.326962  0.470  0.330000  27.912998

# %%
g.sum()
# Out:
#         PassengerId  Survived  Pclass      Age  SibSp  Parch       Fare
# Sex
# female         3815        40     138  1150.00     49     29  1593.7958
# male           8431        14     240  2395.83     47     33  2791.2998

# %%
g.sum()[['Survived','Fare']]
# Out:
#         Survived       Fare
# Sex
# female        40  1593.7958
# male          14  2791.2998

# %%
g.sum()[['Survived','Fare']]
# Out:
#         Survived       Fare
# Sex
# female        40  1593.7958
# male          14  2791.2998

# %%
dfg=g.sum()

# %%
dfg
# Out:
#         PassengerId  Survived  Pclass      Age  SibSp  Parch       Fare
# Sex
# female         3815        40     138  1150.00     49     29  1593.7958
# male           8431        14     240  2395.83     47     33  2791.2998

# %%
dfg.loc['female']  #row data access
# Out:
# PassengerId    3815.0000
# Survived         40.0000
# Pclass          138.0000
# Age            1150.0000
# SibSp            49.0000
# Parch            29.0000
# Fare           1593.7958
# Name: female, dtype: float64

# %%
dfg.transpose()  #transposing the data
# Out:
# Sex             female       male
# PassengerId  3815.0000  8431.0000
# Survived       40.0000    14.0000
# Pclass        138.0000   240.0000
# Age          1150.0000  2395.8300
# SibSp          49.0000    47.0000
# Parch          29.0000    33.0000
# Fare         1593.7958  2791.2998

# %%
#subset of df
df1=df_titanic.iloc[0:5,0:5]

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2=df1
df3=df1

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
pd.concat([df1,df2,df3])  #rowwise concatenation by default axis=0
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# ...

# %%
pd.concat([df1,df2,df3], axis=1)  #colwise concatenation by default axis=1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  PassengerId  \
# 0                            Braund, Mr. Owen Harris    male            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female            2
# 2                             Heikkinen, Miss. Laina  female            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female            4
# 4                           Allen, Mr. William Henry    male            5
#
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# ...

# %%
df4=pd.concat([df1,df2,df3])

# %%
df4
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# ...

# %% [markdown]
# # iloc try to capture inbuilt system generated index integer value

# %%
df4.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Name: 0, dtype: object

# %% [markdown]
# # important-loc try to capture named index as here 0 index is named index here

# %%
df4.loc[0]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex
# 0            1         0       3  Braund, Mr. Owen Harris  male
# 0            1         0       3  Braund, Mr. Owen Harris  male
# 0            1         0       3  Braund, Mr. Owen Harris  male

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [markdown]
# # Merge

# %%
# Creating data frames
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.merge(df1,df2, on='PassengerId')
# Out:
#    PassengerId  Survived_x  Pclass_x  \
# 0            1           0         3
# 1            2           1         1
# 2            3           1         3
# 3            4           1         1
# 4            5           0         3
#
#                                               Name_x   Sex_x  Survived_y  \
# 0                            Braund, Mr. Owen Harris    male           0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           1
# 2                             Heikkinen, Miss. Laina  female           1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           1
# 4                           Allen, Mr. William Henry    male           0
#
#    Pclass_y                                             Name_y   Sex_y
# 0         3                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         3                             Heikkinen, Miss. Laina  female
# ...

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame         ({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left,right)  #like inner join   --(common on key1,key2) in both DFs
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge()

# %%
l = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
r = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
l
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
r
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(l,r)  #inner join on key col-by default
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(l,r,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(l,r,on='key', how='left')   #left outer join
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(l,r,on='key', how='right')   #right outer join
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(l,r,on='key', how='outer')   #full outer join
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %% [markdown]
# # Join Operation

# %%
l.join(r,on='key')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-38b35b33279a> in <module>
# ----> 1 l.join(r,on='key')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ...

# %%
l
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
r
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
l.join(r,lsuffix='-1')  #important
# Out:
#   key-1   A   B key   C   D
# 0    K0  A0  B0  K0  C0  D0
# 1    K8  A1  B1  K1  C1  D1
# 2    K2  A2  B2  K2  C2  D2
# 3    K3  A3  B3  K3  C3  D3

# %% [markdown]
# # adding something throughout the col values

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Apply function -- Column data modification

# %%
#inserting new col and calculting the len of a col

# %%
df_titanic['Name'].apply(len)  #applying len fun throughout the col- Name
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 151    33
# 152    16
# 153    31
# 154    21
# 155    27
# Name: Name, Length: 156, dtype: int64

# %%
#now puting above result in new col in DF

# %%
m=df_titanic['Name'].apply(len)

# %%
df_titanic['newcol']=m

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic['sr_rt_fare']=df_titanic['Fare'].apply(lambda x: np.sqrt(x))

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def fnsqrt(x):
    np.sqrt(x)

# %%
df_titanic['sr_rt_fare_fn']=df_titanic['Fare'].apply(fnsqrt)

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def test(x):
    if x=='female':
        return 0
    else:
        return 1

# %%
df_titanic['flag']=df_titanic['Sex'].apply(test)

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  newcol  sr_rt_fare  \
# 0      0         A/5 21171   7.2500   NaN        S      23    2.692582
# 1      0          PC 17599  71.2833   C85        C      51    8.442944
# 2      0  STON/O2. 3101282   7.9250   NaN        S      22    2.815138
# ...

# %% [markdown]
# # Sort Function

# %%
df_titanic.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 143          144         0       3
# 129          130         0       3
# 131          132         0       3
# 127          128         1       3
# 26            27         0       3
# ..           ...       ...     ...
# 62            63         0       1
# 31            32         1       1
# 118          119         0       1
# 88            89         1       1
# 27            28         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 143                             Burke, Mr. Jeremiah    male  19.0      0
# 129                              Ekstrom, Mr. Johan    male  45.0      0
# 131                  Coelho, Mr. Domingos Fernandeo    male  20.0      0
# 127                       Madsen, Mr. Fridtjof Arne    male  24.0      0
# 26                          Emir, Mr. Farred Chehab    male   NaN      0
# ..                                              ...     ...   ...    ...
# ...

# %%
df_titanic.sort_values(by='Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 143          144         0       3
# 129          130         0       3
# 131          132         0       3
# 127          128         1       3
# 26            27         0       3
# ..           ...       ...     ...
# 62            63         0       1
# 31            32         1       1
# 118          119         0       1
# 88            89         1       1
# 27            28         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 143                             Burke, Mr. Jeremiah    male  19.0      0
# 129                              Ekstrom, Mr. Johan    male  45.0      0
# 131                  Coelho, Mr. Domingos Fernandeo    male  20.0      0
# 127                       Madsen, Mr. Fridtjof Arne    male  24.0      0
# 26                          Emir, Mr. Farred Chehab    male   NaN      0
# ..                                              ...     ...   ...    ...
# ...

# %% [markdown]
# # split() function

# %%
 df0=pd.DataFrame("There is a car".split())

# %%
df0
# Out:
#        0
# 0  There
# 1     is
# 2      a
# 3    car

# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style='darkgrid')

# %%
seaborn parameters:
    sns.relplot(parameters)==>
    data
    kind
    hue
    ci
    markers
    style
    estimator
    x=
    y=
    col=
# Out:
#   File "<ipython-input-3-d0d202510482>", line 1
#     seaborn parameters:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # tips dataset

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Seaborn relation plot- relplot()
#   by default kind='scatter'

# %%
sns.relplot(data=tips, x='total_bill',y='tip')

# %%
sns.relplot(data=tips, x='total_bill',y='tip', hue='sex')

# %%
tips['sex'].value_counts()  #Males are more..same shown in graph above

# %%
sns.relplot(data=tips, x='total_bill',y='tip', hue='sex', style='time')

# %%
tips['time'].value_counts()

# %%
sns.relplot(data=tips, x='total_bill',y='tip', hue='size', style='time') #size is col

# %%
sns.relplot(data=tips, x='total_bill',y='tip', hue='sex', style='time', kind='line') #size is col

# %%
df=pd.DataFrame(np.random.randn(500,2), columns=['time','value'])

# %%
df

# %%
df1=df.cumsum(axis=0)

# %%
df1

# %%
sns.relplot(data=df1, kind='line')

# %%
sns.relplot(data=df1, kind='line', sort=True)

# %% [markdown]
# # fmri dataset

# %%
fmri=sns.load_dataset('fmri')
fmri

# %%
sns.relplot(data=fmri, x='timepoint',y='signal')

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal')

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal', ci='sd')  #ci - confidence interval - standard deviation-parameter added

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',estimator=None) #like original data- width n shape

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',hue='event')

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',hue='region')

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',hue='region', style='event')

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',hue='region', style='event', estimator=None)

# %%
sns.relplot(data=fmri, kind='line',x='timepoint',y='signal',hue='region', style='event', markers=True)

# %%
fmri

# %% [markdown]
# # col values wise splitted graph

# %%
sns.relplot(data=fmri, x='timepoint',y='signal',hue='event', col='region')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ca934062f42d> in <module>
# ----> 1 sns.relplot(data=fmri, x='timepoint',y='signal',hue='event', col='region')
#
# NameError: name 'fmri' is not defined

# %%
tips

# %%
sns.relplot(data=tips, x='total_bill',y='tip',hue='sex', col='time')

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Doubt

# %%
tips1=sns.load_dataset('tips')
tips1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.relplot(data=tips, x='total_bill',y='tip',hue='smoker', col='size')
sns.relplot(x ='total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1455             try:
# -> 1456                 order = vector.cat.categories
#    1457             except (TypeError, AttributeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1459                 try:
# -> 1460                     order = vector.unique()
# ...

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap=3, height=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1455             try:
# -> 1456                 order = vector.cat.categories
#    1457             except (TypeError, AttributeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1459                 try:
# -> 1460                     order = vector.unique()
# ...

# %%
sns.relplot(data=tips, x='total_bill',y='tip',hue='sex', col='size',col_wrap=3, height=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1455             try:
# -> 1456                 order = vector.cat.categories
#    1457             except (TypeError, AttributeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1459                 try:
# -> 1460                     order = vector.unique()
# ...

# %% [markdown]
# # categorical data graph

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#on which day customer paid the highest bill

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='day',y='total_bill',data=tips, jitter=False)  #bydefault true and shows dispersion

# %%
sns.catplot(data=tips, kind='swarm',x='day',y='tip',hue='size' )  #swarm plot not useful
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#how much tip is given by males and females

# %%
sns.catplot(x='sex',y='tip', data=tips)

# %%
sns.catplot(x='sex',y='tip', data=tips, order=['Female','Male'])

# %% [markdown]
# # Outliers are helpful sometime
# #on which day we get exceptional amount of tip by customer

# %%
sns.catplot(x = 'day', y = 'tip', kind = 'box', data = tips, hue = 'sex')

# %%
#now overlapping male/female data using dodge

# %%
sns.catplot(x = 'day', y = 'tip', kind = 'box', data = tips, hue = 'sex', dodge=False)

# %%
d=sns.load_dataset('diamonds')
d
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
d.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'box', data = d.sort_values('color'))

# %%
sns.catplot(x = 'color', y = 'price', kind = 'box', data = d.sort_values('color'))  #boxen instead of box

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips, dodge = False)

# %% [markdown]
# # Violin plot

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True)

# %%
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # we can merge diff plots in one plot

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Count Plot

# %%
sns.catplot(x = 'deck', kind = 'count', palette = 'ch:0.95', data = titanic, hue = 'class')

# %% [markdown]
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %% [markdown]
# # Displot()

# %%
from numpy.random import randn as ri
x = ri(100)

# %%
x
# Out:
# array([ 6.43403304e-01,  7.28949867e-01, -6.04612378e-01, -4.41821212e-01,
#         1.41777475e+00, -1.14129982e+00, -6.26294802e-01,  8.85093462e-01,
#        -1.55659884e+00, -1.16915484e+00, -3.81803547e-01, -1.58016545e-01,
#        -1.40268441e+00, -1.54512436e+00,  4.93363212e-01, -1.41311732e+00,
#         7.41448853e-01, -7.64927183e-01,  1.81142728e-01, -3.60470924e-01,
#        -4.92162985e-01, -1.48302747e+00,  4.45099104e-01,  1.12691651e-02,
#        -6.68608113e-01, -4.98911505e-01, -2.62864597e+00,  2.54753218e+00,
#        -2.48458002e+00, -3.26722811e-01,  9.73814397e-01, -9.33055562e-01,
#        -7.04587857e-01, -2.17936505e-01,  6.50942483e-01,  2.57921716e-01,
#         6.36672792e-01,  8.59859070e-01, -3.43981570e-01, -1.03571626e+00,
#         9.09328034e-01,  1.63530878e+00,  1.55093206e+00, -1.07239188e+00,
#         1.96097511e-01, -6.16190530e-02,  1.04045194e-01,  1.45834302e-02,
# ...

# %%
#random data is always normalized
#if we will inc data, the grapgh of this data will be more normalized

# %% [markdown]
# # join of bar and histogram plts==>displot=>distribution plot

# %%
sns.distplot(x,bins=25)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x, kde = True, hist = True, rug= False, bins= 30)

# %% [markdown]
# # Joinplot()

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x = x, y=y)

# %%
sns.set()
sns.jointplot(x = x, y=y, kind = 'hex')

# %%
sns.jointplot(x = x, y=y, kind = 'kde')

# %%
f, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
g.ax_joint.collections[0].set_alpha(0)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Pairplot()- same as scatter matrix

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %% [markdown]
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)

# %%
data = sns.load_dataset('anscombe')
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
data['dataset'].value_counts()
# Out:
# III    11
# IV     11
# II     11
# I      11
# Name: dataset, dtype: int64

# %%
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap=2, height = 4)

# %% [markdown]
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x+i*0.5)*(7-i))

# %%
sinplot()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})
sinplot()
sns.despine(left = True, bottom= False)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'in',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')

# %%
sns.set_context('talk', font_scale=1.5)
sinplot()

# %%
current_palettes = sns.color_palette()
sns.palplot(current_palettes)

# %%
sns.palplot(sns.color_palette('hls', 8))

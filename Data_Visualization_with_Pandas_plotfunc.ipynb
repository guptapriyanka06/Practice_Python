# %%
Visualization Libraries:
    matplotlib
    seaborn
    pyplot-popular/powerful
    cufflinks
    bokeh-popular
    pandas plot
    D3js  --(Data Driven Documents) needs little knowledge of java script
    
  #these libraries by default installed in anaconda installation- for Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline #in old version of anaconda, it was to show the graph but new version its not required

# %% [markdown]
# # Iris Dataset

# %%
iris=sns.load_dataset('iris')  #it is available in seaborn library
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot()  #pandas plotting here
# Out:
# <AxesSubplot:>

# %%
iris.plot(legend=True,figsize=(10,5), logy=True)   #logarithmic function
# Out:
# <AxesSubplot:>

# %% [markdown]
# # line plot for each feature

# %%
iris.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
iris.plot(subplots=True, sharex=False,layout=(2,2), figsize=(15,8))  #layout kinf of frame 2X2  , sharex means x-axis labels will be shared or not
plt.tight_layout()

# %%
df=iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()  #other way of above
# Out:
# <AxesSubplot:>

# %%
df_titanic=sns.load_dataset('titanic')
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df_titanic['pclass'].plot()
# Out:
# <AxesSubplot:>

# %%
df_titanic['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_titanic['pclass'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_titanic['pclass'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # value_counts() of each pclass-graph

# %%
df_titanic['pclass'].value_counts().plot(kind='bar') #value_counts graph of pclass
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(10,5))
df
# Out:
#           0         1         2         3         4
# 0 -1.074538 -0.002648 -0.905497 -0.228598  0.782444
# 1 -0.541728  1.630828  1.612015 -1.131726  1.489418
# 2 -0.406164 -1.013886 -0.541481 -0.403412 -0.426515
# 3  0.058979 -0.316004  0.453419 -1.567159 -0.041800
# 4  0.300599  0.421943  1.549397 -0.947641  0.306897
# 5 -0.369561  0.012291  1.320501  1.241719 -0.736902
# 6 -0.759737 -1.325188 -1.366174  0.429578  1.305980
# 7  3.199937 -2.073713  0.239742  2.051993  2.173037
# 8 -2.483941  0.647935  0.082222  0.021935  0.032868
# 9  0.231672  0.703502 -0.259705  1.372626  0.106310

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.head() #see this data above in bar graph- each group of 4 color is 1 record
# Out:
#           0         1         2         3         4
# 0 -1.074538 -0.002648 -0.905497 -0.228598  0.782444
# 1 -0.541728  1.630828  1.612015 -1.131726  1.489418
# 2 -0.406164 -1.013886 -0.541481 -0.403412 -0.426515
# 3  0.058979 -0.316004  0.453419 -1.567159 -0.041800
# 4  0.300599  0.421943  1.549397 -0.947641  0.306897

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Line graph

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Histogram - imp- y-axis frequency- how many data (no. of occurences of particular data in particular range) we have in a interval on x-axis

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#above data may be overlapped in above histogram so we can do below way

# %%
iris['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='hist', stacked=True, bins=100) #stacked=true- means smaller one front-bigger behind
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=False, bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=True, bins=100,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.hist(color='r',alpha=.2)  #alpha is for less intensity of color ,some hexacode for colors can be usealso ..see on google
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.hist(color='r',alpha=.2, figsize=(10,10))  #figure size
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Scatter Polt-----Now see the relationship between two or more cols

# %%
#relationship beetween sepal length and sepal width

# %%
iris.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x='sepal_length',y='petal_length')  #showing more relationship like linear
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',color='b', figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # scatter plot with third col

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',figsize=(5,5),c='sepal_width',s=200)  #s is for size of dots
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.hexbin(x='sepal_length',y='petal_length',figsize=(5,5),C='sepal_width',gridsize=20)  #s is for size of dots
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Pie Chart-percentage distribution of dataset

# %%
data=iris.iloc[0]

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data  #for single record
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
data.plot.pie() #for single record
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
p=df.iloc[0:3].T
p
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
p.plot.pie(subplots=True, figsize=(20,20),autopct='%.5f')  #showing col 0,1,2 ..means for each record diff pie chart
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# # scatter matrix-relation between diff cols-compare every dataset with every dataset

# %%
pd.plotting.scatter_matrix(iris,figsize=(10,10),color='r',alpha=.9)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %% [markdown]
# # scatter matrix with kde useful for Normal Distribution

# %% [markdown]
# # kde=> diagonal grapgs(same col vs same col) showing data for a each col is normaly distributed or not?
# if dataset is not normalized then for sure you have to normalize the data for that particular feature.
# in below scatter matrix, only one col is normalized which is bell shaped curve.

# %%
pd.plotting.scatter_matrix(iris,figsize=(10,10),color='r',alpha=.9,diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %% [markdown]
# now for single col to check normalize or not using kde??

# %%
df['sepal_length'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#line plot

# %%
iris['sepal_length'].plot(style='r--',label="sepal",legend=True)
# Out:
# <AxesSubplot:>
